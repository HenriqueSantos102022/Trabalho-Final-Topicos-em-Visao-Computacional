# %% [markdown]
# # Configurações, Caminhos e Importações

# %%
import os
import random
import numpy as np
import pandas as pd
import glob
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from google.colab import drive

# Seeds para reprodutibilidade
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

drive.mount('/content/drive')

# --- CONFIGURAÇÃO DE CAMINHOS ---
dataset_path = '/content/drive/MyDrive/TCC/PKG - Osteosarcoma Tumor Assessment'
csv_path = '/content/drive/MyDrive/TCC/ML_Features_1144.csv'
save_model_path = '/content/drive/MyDrive/TCC/Modelos_Osteosarcoma'

os.makedirs(save_model_path, exist_ok=True)

# NOMES PARA A MOBILENET V2
checkpoint_path = os.path.join(save_model_path, 'melhor_modelo_MobileNetV2_3classes_bruto_temp.keras')
final_model_name = os.path.join(save_model_path, 'MobileNetV2_Osteosarcoma_3classes_bruto_Final.keras')

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Mapeamento e Agrupamento das 3 Classes

# %%
print("Iniciando carregamento e agrupamento (3 Classes)...")
df_original = pd.read_csv(csv_path)

# Criando uma cópia
df_copia = df_original.copy()

# ==============================================================================
# ALTERAÇÃO DO DATASET: Mesclando 'viable: non-viable' em 'Viable'
# ==============================================================================
df_copia['classification'] = df_copia['classification'].replace('viable: non-viable', 'Viable')

print("\nDistribuição de Classes para a MobileNetV2:")
print(df_copia['classification'].value_counts())

all_image_paths = glob.glob(os.path.join(dataset_path, '**', '*.jpg'), recursive=True)
all_image_paths += glob.glob(os.path.join(dataset_path, '**', '*.JPG'), recursive=True)

normalized_path_lookup = {}
for p in all_image_paths:
    base = os.path.basename(p)
    name_no_ext = os.path.splitext(base)[0]
    norm_name = name_no_ext.lower().replace(" ", "").replace("-", "").replace("_", "")
    normalized_path_lookup[norm_name] = p

def get_full_path_robust(image_name):
    if pd.isna(image_name): return None
    norm_csv_name = str(image_name).lower().replace(" ", "").replace("-", "").replace("_", "")
    return normalized_path_lookup.get(norm_csv_name)

df_copia['full_path'] = df_copia['image.name'].apply(get_full_path_robust)
df_final = df_copia.dropna(subset=['full_path']).copy()

print(f"\nTotal de imagens mapeadas: {len(df_final)} / 1144")
# Out:
# Iniciando carregamento e agrupamento (3 Classes)...
#
# Distribuição de Classes para a MobileNetV2:
# classification
# Non-Tumor           536
# Viable              345
# Non-Viable-Tumor    263
# Name: count, dtype: int64
#
# Total de imagens mapeadas: 1144 / 1144

# %% [markdown]
# # Divisão e Geradores

# %%
train_df, temp_df = train_test_split(
    df_final, train_size=0.7, stratify=df_final['classification'], random_state=RANDOM_SEED
)
val_df, test_df = train_test_split(
    temp_df, train_size=0.5, stratify=temp_df['classification'], random_state=RANDOM_SEED
)

# Gerador bruto (Sem CLAHE, apenas a normalização obrigatória da MobileNetV2)
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = datagen.flow_from_dataframe(
    train_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True
)

val_gen = datagen.flow_from_dataframe(
    val_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

test_gen = datagen.flow_from_dataframe(
    test_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
# Out:
# Found 800 validated image filenames belonging to 3 classes.
# Found 172 validated image filenames belonging to 3 classes.
# Found 172 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Arquitetura MobileNetV2 e Treinamento

# %%
def build_model_osteo_mobilenet(num_classes=3):
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model_osteo_mobilenet(num_classes=3)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1)
]

print("Iniciando Treinamento (MobileNetV2 | 3 Classes | BRUTO)...")
history = model.fit(
    train_gen, validation_data=val_gen,
    epochs=EPOCHS, callbacks=callbacks, verbose=1
)

model.save(final_model_name)
print(f"Treinamento concluído! Modelo salvo em: {final_model_name}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Iniciando Treinamento (MobileNetV2 | 3 Classes | BRUTO)...
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.4943 - loss: 1.1239
# Epoch 1: val_loss improved from None to 0.40650, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 426s 16s/step - accuracy: 0.6150 - loss: 0.8865 - val_accuracy: 0.8663 - val_loss: 0.4065
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.8150 - loss: 0.4677
# Epoch 2: val_loss improved from 0.40650 to 0.31880, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 486ms/step - accuracy: 0.8288 - loss: 0.4350 - val_accuracy: 0.8895 - val_loss: 0.3188
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.8773 - loss: 0.3611
# Epoch 3: val_loss improved from 0.31880 to 0.31302, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 491ms/step - accuracy: 0.8687 - loss: 0.3584 - val_accuracy: 0.8895 - val_loss: 0.3130
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.8812 - loss: 0.3312
# Epoch 4: val_loss improved from 0.31302 to 0.29612, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 474ms/step - accuracy: 0.8850 - loss: 0.3317 - val_accuracy: 0.8953 - val_loss: 0.2961
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.8907 - loss: 0.3013
# Epoch 5: val_loss improved from 0.29612 to 0.27736, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 485ms/step - accuracy: 0.8900 - loss: 0.2874 - val_accuracy: 0.9070 - val_loss: 0.2774
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9019 - loss: 0.2673
# Epoch 6: val_loss improved from 0.27736 to 0.27237, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 481ms/step - accuracy: 0.9038 - loss: 0.2549 - val_accuracy: 0.9128 - val_loss: 0.2724
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9194 - loss: 0.2360
# Epoch 7: val_loss did not improve from 0.27237
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 440ms/step - accuracy: 0.9200 - loss: 0.2252 - val_accuracy: 0.9012 - val_loss: 0.2816
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9285 - loss: 0.2055
# Epoch 8: val_loss improved from 0.27237 to 0.27029, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 475ms/step - accuracy: 0.9250 - loss: 0.2115 - val_accuracy: 0.9070 - val_loss: 0.2703
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.9219 - loss: 0.1930
# Epoch 9: val_loss did not improve from 0.27029
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 461ms/step - accuracy: 0.9212 - loss: 0.2124 - val_accuracy: 0.8779 - val_loss: 0.2851
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9338 - loss: 0.1717
# Epoch 10: val_loss improved from 0.27029 to 0.26437, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_MobileNetV2_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 494ms/step - accuracy: 0.9175 - loss: 0.2050 - val_accuracy: 0.8953 - val_loss: 0.2644
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9420 - loss: 0.1655
# Epoch 11: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 458ms/step - accuracy: 0.9300 - loss: 0.1899 - val_accuracy: 0.8953 - val_loss: 0.2706
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9462 - loss: 0.1662
# Epoch 12: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 451ms/step - accuracy: 0.9413 - loss: 0.1766 - val_accuracy: 0.9012 - val_loss: 0.2684
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9224 - loss: 0.1803
# Epoch 13: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 457ms/step - accuracy: 0.9287 - loss: 0.1808 - val_accuracy: 0.8895 - val_loss: 0.2714
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9374 - loss: 0.1515
# Epoch 14: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 432ms/step - accuracy: 0.9375 - loss: 0.1617 - val_accuracy: 0.9128 - val_loss: 0.2711
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9529 - loss: 0.1450
# Epoch 15: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 444ms/step - accuracy: 0.9475 - loss: 0.1610 - val_accuracy: 0.8895 - val_loss: 0.2661
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9436 - loss: 0.1546
# Epoch 16: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 461ms/step - accuracy: 0.9450 - loss: 0.1407 - val_accuracy: 0.8895 - val_loss: 0.2721
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9521 - loss: 0.1270
# Epoch 17: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 460ms/step - accuracy: 0.9425 - loss: 0.1331 - val_accuracy: 0.8837 - val_loss: 0.2754
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9633 - loss: 0.1228
# Epoch 18: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 447ms/step - accuracy: 0.9525 - loss: 0.1346 - val_accuracy: 0.8953 - val_loss: 0.2706
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9578 - loss: 0.1331
# Epoch 19: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 434ms/step - accuracy: 0.9575 - loss: 0.1309 - val_accuracy: 0.9012 - val_loss: 0.2671
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9544 - loss: 0.1230
# Epoch 20: val_loss did not improve from 0.26437
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 468ms/step - accuracy: 0.9463 - loss: 0.1320 - val_accuracy: 0.9012 - val_loss: 0.2797
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.
# Treinamento concluído! Modelo salvo em: /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/MobileNetV2_Osteosarcoma_3classes_bruto_Final.keras

# %% [markdown]
# # Avaliação Final

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# 1. Gráficos de Evolução do Treino
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Treino')
plt.plot(history.history['val_accuracy'], label='Validação')
plt.title('Acurácia (MobileNetV2 - BRUTO)')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Loss (MobileNetV2 - BRUTO)')
plt.legend()
plt.show()

# 2. Predição no conjunto de Teste
test_gen.reset()
Y_pred = model.predict(test_gen)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_gen.classes
class_labels = list(test_gen.class_indices.keys())

# 3. Relatório de Classificação Detalhado
print("\n--- RELATÓRIO DE CLASSIFICAÇÃO (MobileNetV2) ---")
print(classification_report(y_true, y_pred, target_names=class_labels, digits=4))

# 4. Matriz de Confusão
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão - MobileNetV2 (3 Classes, BRUTO)')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 59s 11s/step
#
# --- RELATÓRIO DE CLASSIFICAÇÃO (MobileNetV2) ---
#                   precision    recall  f1-score   support
#
#        Non-Tumor     0.9277    0.9506    0.9390        81
# Non-Viable-Tumor     0.9487    0.9487    0.9487        39
#           Viable     0.9400    0.9038    0.9216        52
#
#         accuracy                         0.9360       172
#        macro avg     0.9388    0.9344    0.9364       172
#     weighted avg     0.9362    0.9360    0.9359       172
