# %% [markdown]
# # Configurações, Caminhos e Importações

# %%
import os
import random
import numpy as np
import pandas as pd
import glob
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from google.colab import drive

# Seeds para reprodutibilidade
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

drive.mount('/content/drive')

# --- CONFIGURAÇÃO DE CAMINHOS ---
dataset_path = '/content/drive/MyDrive/TCC/PKG - Osteosarcoma Tumor Assessment'
csv_path = '/content/drive/MyDrive/TCC/ML_Features_1144.csv'
save_model_path = '/content/drive/MyDrive/TCC/Modelos_Osteosarcoma'

os.makedirs(save_model_path, exist_ok=True)

# NOMES PARA A EFFICIENTNET B2
checkpoint_path = os.path.join(save_model_path, 'melhor_modelo_B2_3classes_BRUTO_temp.keras')
final_model_name = os.path.join(save_model_path, 'EfficientNetB2_Osteosarcoma_3classes_BRUTO_Final.keras')

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Mapeamento e Agrupamento das Classes

# %%
print("Iniciando carregamento e mapeamento...")
df_original = pd.read_csv(csv_path)

# Criando uma cópia
df_copia = df_original.copy()

# ==============================================================================
# ALTERAÇÃO DO DATASET: Mesclando 'viable: non-viable' em 'Viable'
# ==============================================================================
df_copia['classification'] = df_copia['classification'].replace('viable: non-viable', 'Viable')

print("\nDistribuição das classes para o teste bruto de 3 classes:")
print(df_copia['classification'].value_counts())

# Mapeamento dos caminhos das imagens
all_image_paths = glob.glob(os.path.join(dataset_path, '**', '*.jpg'), recursive=True)
all_image_paths += glob.glob(os.path.join(dataset_path, '**', '*.JPG'), recursive=True)

normalized_path_lookup = {}
for p in all_image_paths:
    base = os.path.basename(p)
    name_no_ext = os.path.splitext(base)[0]
    norm_name = name_no_ext.lower().replace(" ", "").replace("-", "").replace("_", "")
    normalized_path_lookup[norm_name] = p

def get_full_path_robust(image_name):
    if pd.isna(image_name): return None
    norm_csv_name = str(image_name).lower().replace(" ", "").replace("-", "").replace("_", "")
    return normalized_path_lookup.get(norm_csv_name)

df_copia['full_path'] = df_copia['image.name'].apply(get_full_path_robust)
df_final = df_copia.dropna(subset=['full_path']).copy()

print(f"\nTotal de imagens mapeadas com sucesso: {len(df_final)} / 1144")
# Out:
# Iniciando carregamento e mapeamento...
#
# Distribuição das classes para o teste bruto de 3 classes:
# classification
# Non-Tumor           536
# Viable              345
# Non-Viable-Tumor    263
# Name: count, dtype: int64
#
# Total de imagens mapeadas com sucesso: 1144 / 1144

# %% [markdown]
# # Divisão de Dados e Geradores (Sem pré-processamento)

# %%
# Divisão (70/15/15)
train_df, temp_df = train_test_split(
    df_final, train_size=0.7, stratify=df_final['classification'], random_state=RANDOM_SEED
)
val_df, test_df = train_test_split(
    temp_df, train_size=0.5, stratify=temp_df['classification'], random_state=RANDOM_SEED
)

# Gerador sem CLAHE
datagen = ImageDataGenerator()

train_gen = datagen.flow_from_dataframe(
    train_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True
)

val_gen = datagen.flow_from_dataframe(
    val_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

test_gen = datagen.flow_from_dataframe(
    test_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
# Out:
# Found 800 validated image filenames belonging to 3 classes.
# Found 172 validated image filenames belonging to 3 classes.
# Found 172 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Arquitetura EfficientNetB2 e Treinamento

# %%
def build_model_osteo_b2(num_classes=3):

    base_model = EfficientNetB2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    base_model.trainable = False

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model_osteo_b2(num_classes=3)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1)
]

print("Iniciando Treinamento (EfficientNetB2 | 3 Classes | BRUTO)...")
history = model.fit(
    train_gen, validation_data=val_gen,
    epochs=EPOCHS, callbacks=callbacks, verbose=1
)

model.save(final_model_name)
print(f"Treinamento concluído! Modelo salvo em: {final_model_name}")
# Out:
# Iniciando Treinamento (EfficientNetB2 | 3 Classes | BRUTO)...
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 23s/step - accuracy: 0.5148 - loss: 1.0031
# Epoch 1: val_loss improved from None to 0.53552, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 791s 30s/step - accuracy: 0.6112 - loss: 0.8504 - val_accuracy: 0.8140 - val_loss: 0.5355
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.8043 - loss: 0.5461
# Epoch 2: val_loss improved from 0.53552 to 0.41183, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 461ms/step - accuracy: 0.8125 - loss: 0.5135 - val_accuracy: 0.8314 - val_loss: 0.4118
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.8845 - loss: 0.3690
# Epoch 3: val_loss improved from 0.41183 to 0.36001, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 494ms/step - accuracy: 0.8637 - loss: 0.4123 - val_accuracy: 0.8779 - val_loss: 0.3600
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step - accuracy: 0.8764 - loss: 0.4018
# Epoch 4: val_loss improved from 0.36001 to 0.32840, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 425ms/step - accuracy: 0.8850 - loss: 0.3748 - val_accuracy: 0.9012 - val_loss: 0.3284
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8853 - loss: 0.3382
# Epoch 5: val_loss improved from 0.32840 to 0.31134, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 479ms/step - accuracy: 0.8888 - loss: 0.3369 - val_accuracy: 0.9012 - val_loss: 0.3113
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.8903 - loss: 0.3502
# Epoch 6: val_loss improved from 0.31134 to 0.29369, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 470ms/step - accuracy: 0.8963 - loss: 0.3228 - val_accuracy: 0.9070 - val_loss: 0.2937
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9141 - loss: 0.2953
# Epoch 7: val_loss improved from 0.29369 to 0.28518, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 479ms/step - accuracy: 0.9087 - loss: 0.2859 - val_accuracy: 0.8953 - val_loss: 0.2852
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8954 - loss: 0.3062
# Epoch 8: val_loss improved from 0.28518 to 0.27458, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 435ms/step - accuracy: 0.9112 - loss: 0.2796 - val_accuracy: 0.8953 - val_loss: 0.2746
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9036 - loss: 0.2769
# Epoch 9: val_loss improved from 0.27458 to 0.27362, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 430ms/step - accuracy: 0.9087 - loss: 0.2627 - val_accuracy: 0.9070 - val_loss: 0.2736
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9236 - loss: 0.2355
# Epoch 10: val_loss improved from 0.27362 to 0.26563, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 481ms/step - accuracy: 0.9250 - loss: 0.2487 - val_accuracy: 0.8953 - val_loss: 0.2656
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9297 - loss: 0.2305
# Epoch 11: val_loss improved from 0.26563 to 0.26437, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 474ms/step - accuracy: 0.9200 - loss: 0.2452 - val_accuracy: 0.9070 - val_loss: 0.2644
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9286 - loss: 0.2229
# Epoch 12: val_loss improved from 0.26437 to 0.26006, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 476ms/step - accuracy: 0.9212 - loss: 0.2420 - val_accuracy: 0.9070 - val_loss: 0.2601
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9053 - loss: 0.2542
# Epoch 13: val_loss improved from 0.26006 to 0.25527, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 437ms/step - accuracy: 0.9125 - loss: 0.2428 - val_accuracy: 0.9186 - val_loss: 0.2553
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - accuracy: 0.9272 - loss: 0.2093
# Epoch 14: val_loss improved from 0.25527 to 0.25159, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 450ms/step - accuracy: 0.9112 - loss: 0.2273 - val_accuracy: 0.9128 - val_loss: 0.2516
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9454 - loss: 0.2048
# Epoch 15: val_loss improved from 0.25159 to 0.24456, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 471ms/step - accuracy: 0.9375 - loss: 0.2144 - val_accuracy: 0.9244 - val_loss: 0.2446
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9415 - loss: 0.1917
# Epoch 16: val_loss improved from 0.24456 to 0.24091, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 477ms/step - accuracy: 0.9325 - loss: 0.2082 - val_accuracy: 0.9244 - val_loss: 0.2409
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - accuracy: 0.9415 - loss: 0.1982
# Epoch 17: val_loss did not improve from 0.24091
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 364ms/step - accuracy: 0.9375 - loss: 0.2003 - val_accuracy: 0.9128 - val_loss: 0.2417
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9340 - loss: 0.2064
# Epoch 18: val_loss improved from 0.24091 to 0.24000, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 489ms/step - accuracy: 0.9362 - loss: 0.1936 - val_accuracy: 0.9244 - val_loss: 0.2400
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.9162 - loss: 0.2161
# Epoch 19: val_loss did not improve from 0.24000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 427ms/step - accuracy: 0.9350 - loss: 0.1945 - val_accuracy: 0.9128 - val_loss: 0.2422
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step - accuracy: 0.9576 - loss: 0.1621
# Epoch 20: val_loss improved from 0.24000 to 0.23848, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 20: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 448ms/step - accuracy: 0.9450 - loss: 0.1873 - val_accuracy: 0.9186 - val_loss: 0.2385
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.9384 - loss: 0.1769
# Epoch 21: val_loss improved from 0.23848 to 0.23419, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 21: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 463ms/step - accuracy: 0.9425 - loss: 0.1808 - val_accuracy: 0.9302 - val_loss: 0.2342
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9391 - loss: 0.1736
# Epoch 22: val_loss did not improve from 0.23419
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 395ms/step - accuracy: 0.9400 - loss: 0.1762 - val_accuracy: 0.9244 - val_loss: 0.2361
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.9474 - loss: 0.1678
# Epoch 23: val_loss improved from 0.23419 to 0.23248, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 23: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 488ms/step - accuracy: 0.9463 - loss: 0.1765 - val_accuracy: 0.9128 - val_loss: 0.2325
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9556 - loss: 0.1715
# Epoch 24: val_loss did not improve from 0.23248
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 402ms/step - accuracy: 0.9438 - loss: 0.1752 - val_accuracy: 0.9244 - val_loss: 0.2342
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9577 - loss: 0.1528
# Epoch 25: val_loss did not improve from 0.23248
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 377ms/step - accuracy: 0.9500 - loss: 0.1666 - val_accuracy: 0.9186 - val_loss: 0.2363
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9385 - loss: 0.1885
# Epoch 26: val_loss improved from 0.23248 to 0.22848, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 26: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 427ms/step - accuracy: 0.9362 - loss: 0.1853 - val_accuracy: 0.9070 - val_loss: 0.2285
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9605 - loss: 0.1434
# Epoch 27: val_loss did not improve from 0.22848
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 404ms/step - accuracy: 0.9488 - loss: 0.1674 - val_accuracy: 0.9186 - val_loss: 0.2323
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9464 - loss: 0.1707
# Epoch 28: val_loss did not improve from 0.22848
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 420ms/step - accuracy: 0.9450 - loss: 0.1660 - val_accuracy: 0.8953 - val_loss: 0.2356
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9536 - loss: 0.1691
# Epoch 29: val_loss improved from 0.22848 to 0.22580, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 29: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 422ms/step - accuracy: 0.9525 - loss: 0.1618 - val_accuracy: 0.9128 - val_loss: 0.2258
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step - accuracy: 0.9627 - loss: 0.1409
# Epoch 30: val_loss improved from 0.22580 to 0.22287, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 30: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 459ms/step - accuracy: 0.9600 - loss: 0.1489 - val_accuracy: 0.9128 - val_loss: 0.2229
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9530 - loss: 0.1302
# Epoch 31: val_loss did not improve from 0.22287
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 429ms/step - accuracy: 0.9538 - loss: 0.1362 - val_accuracy: 0.9244 - val_loss: 0.2262
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.9533 - loss: 0.1547
# Epoch 32: val_loss did not improve from 0.22287
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 396ms/step - accuracy: 0.9500 - loss: 0.1496 - val_accuracy: 0.9186 - val_loss: 0.2292
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - accuracy: 0.9564 - loss: 0.1468
# Epoch 33: val_loss did not improve from 0.22287
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 389ms/step - accuracy: 0.9550 - loss: 0.1509 - val_accuracy: 0.9128 - val_loss: 0.2280
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9726 - loss: 0.1286
# Epoch 34: val_loss did not improve from 0.22287
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 402ms/step - accuracy: 0.9638 - loss: 0.1454 - val_accuracy: 0.9244 - val_loss: 0.2329
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step - accuracy: 0.9376 - loss: 0.1851
# Epoch 35: val_loss did not improve from 0.22287
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 415ms/step - accuracy: 0.9488 - loss: 0.1499 - val_accuracy: 0.9186 - val_loss: 0.2237
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.9610 - loss: 0.1344
# Epoch 36: val_loss did not improve from 0.22287
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - accuracy: 0.9538 - loss: 0.1524 - val_accuracy: 0.9244 - val_loss: 0.2270
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9372 - loss: 0.1522
# Epoch 37: val_loss did not improve from 0.22287
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 398ms/step - accuracy: 0.9488 - loss: 0.1413 - val_accuracy: 0.9302 - val_loss: 0.2272
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9662 - loss: 0.1533
# Epoch 38: val_loss improved from 0.22287 to 0.21974, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 38: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 439ms/step - accuracy: 0.9625 - loss: 0.1399 - val_accuracy: 0.9302 - val_loss: 0.2197
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - accuracy: 0.9664 - loss: 0.1215
# Epoch 39: val_loss improved from 0.21974 to 0.21830, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
#
# Epoch 39: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_B2_3classes_BRUTO_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 445ms/step - accuracy: 0.9613 - loss: 0.1275 - val_accuracy: 0.9360 - val_loss: 0.2183
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.9705 - loss: 0.1181
# Epoch 40: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 375ms/step - accuracy: 0.9600 - loss: 0.1390 - val_accuracy: 0.9186 - val_loss: 0.2227
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9669 - loss: 0.1150
# Epoch 41: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 418ms/step - accuracy: 0.9588 - loss: 0.1310 - val_accuracy: 0.9302 - val_loss: 0.2215
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.9605 - loss: 0.1266
# Epoch 42: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 382ms/step - accuracy: 0.9563 - loss: 0.1368 - val_accuracy: 0.9360 - val_loss: 0.2208
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 0.9618 - loss: 0.1337
# Epoch 43: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 380ms/step - accuracy: 0.9638 - loss: 0.1279 - val_accuracy: 0.9419 - val_loss: 0.2209
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9649 - loss: 0.1195
# Epoch 44: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 394ms/step - accuracy: 0.9563 - loss: 0.1363 - val_accuracy: 0.9244 - val_loss: 0.2252
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9699 - loss: 0.1336
# Epoch 45: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 403ms/step - accuracy: 0.9737 - loss: 0.1233 - val_accuracy: 0.9244 - val_loss: 0.2236
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9711 - loss: 0.1069
# Epoch 46: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step - accuracy: 0.9675 - loss: 0.1170 - val_accuracy: 0.9244 - val_loss: 0.2297
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9662 - loss: 0.1189
# Epoch 47: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 405ms/step - accuracy: 0.9650 - loss: 0.1274 - val_accuracy: 0.9302 - val_loss: 0.2243
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9717 - loss: 0.1131
# Epoch 48: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 393ms/step - accuracy: 0.9625 - loss: 0.1219 - val_accuracy: 0.9302 - val_loss: 0.2236
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - accuracy: 0.9684 - loss: 0.1173
# Epoch 49: val_loss did not improve from 0.21830
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step - accuracy: 0.9725 - loss: 0.1117 - val_accuracy: 0.9244 - val_loss: 0.2283
# Epoch 49: early stopping
# Restoring model weights from the end of the best epoch: 39.
# Treinamento concluído! Modelo salvo em: /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/EfficientNetB2_Osteosarcoma_3classes_BRUTO_Final.keras

# %% [markdown]
# # Avaliação Final

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# Gráficos
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Treino')
plt.plot(history.history['val_accuracy'], label='Validação')
plt.title('Acurácia (EfficientNetB2 - BRUTO)')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Loss (EfficientNetB2 - BRUTO)')
plt.legend()
plt.show()

# Predição
test_gen.reset()
Y_pred = model.predict(test_gen)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_gen.classes
class_labels = list(test_gen.class_indices.keys())

# Relatório
print("\n--- RELATÓRIO DE CLASSIFICAÇÃO (EfficientNetB2) ---")
print(classification_report(y_true, y_pred, target_names=class_labels, digits=4))

# Matriz
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão - EfficientNetB2 (3 Classes, BRUTO)')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 108s 20s/step
#
# --- RELATÓRIO DE CLASSIFICAÇÃO (EfficientNetB2) ---
#                   precision    recall  f1-score   support
#
#        Non-Tumor     0.9620    0.9383    0.9500        81
# Non-Viable-Tumor     0.9286    1.0000    0.9630        39
#           Viable     0.9412    0.9231    0.9320        52
#
#         accuracy                         0.9477       172
#        macro avg     0.9439    0.9538    0.9483       172
#     weighted avg     0.9481    0.9477    0.9475       172
