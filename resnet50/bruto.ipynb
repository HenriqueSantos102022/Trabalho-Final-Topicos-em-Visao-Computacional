# %% [markdown]
# # Configurações, Caminhos e Importações

# %%
import os
import random
import numpy as np
import pandas as pd
import glob
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from google.colab import drive

# Seeds para reprodutibilidade
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

drive.mount('/content/drive')

# --- CONFIGURAÇÃO DE CAMINHOS ---
dataset_path = '/content/drive/MyDrive/TCC/PKG - Osteosarcoma Tumor Assessment'
csv_path = '/content/drive/MyDrive/TCC/ML_Features_1144.csv'
save_model_path = '/content/drive/MyDrive/TCC/Modelos_Osteosarcoma'

os.makedirs(save_model_path, exist_ok=True)

# NOMES PARA O TESTE BRUTO (ResNet50 | 3 Classes)
checkpoint_path = os.path.join(save_model_path, 'melhor_modelo_ResNet50_3classes_bruto_temp.keras')
final_model_name = os.path.join(save_model_path, 'ResNet50_Osteosarcoma_3classes_bruto_Final.keras')

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Mapeamento e Agrupamento das Classes

# %%
print("Iniciando carregamento e agrupamento (3 Classes)...")
df_original = pd.read_csv(csv_path)

# Criando cópia
df_copia = df_original.copy()

# ==============================================================================
# ALTERAÇÃO DO DATASET: Mesclando 'viable: non-viable' em 'Viable'
# ==============================================================================
df_copia['classification'] = df_copia['classification'].replace('viable: non-viable', 'Viable')

print("\nDistribuição das classes para o teste bruto (ResNet50):")
print(df_copia['classification'].value_counts())

all_image_paths = glob.glob(os.path.join(dataset_path, '**', '*.jpg'), recursive=True)
all_image_paths += glob.glob(os.path.join(dataset_path, '**', '*.JPG'), recursive=True)

normalized_path_lookup = {}
for p in all_image_paths:
    base = os.path.basename(p)
    name_no_ext = os.path.splitext(base)[0]
    norm_name = name_no_ext.lower().replace(" ", "").replace("-", "").replace("_", "")
    normalized_path_lookup[norm_name] = p

def get_full_path_robust(image_name):
    if pd.isna(image_name): return None
    norm_csv_name = str(image_name).lower().replace(" ", "").replace("-", "").replace("_", "")
    return normalized_path_lookup.get(norm_csv_name)

df_copia['full_path'] = df_copia['image.name'].apply(get_full_path_robust)
df_final = df_copia.dropna(subset=['full_path']).copy()

print(f"\nTotal de imagens mapeadas com sucesso: {len(df_final)} / 1144")
# Out:
# Iniciando carregamento e agrupamento (3 Classes)...
#
# Distribuição das classes para o teste bruto (ResNet50):
# classification
# Non-Tumor           536
# Viable              345
# Non-Viable-Tumor    263
# Name: count, dtype: int64
#
# Total de imagens mapeadas com sucesso: 1144 / 1144

# %% [markdown]
# # Divisão de Dados e Geradores

# %%
# 1. Divisão estratificada (70/15/15)
train_df, temp_df = train_test_split(
    df_final, train_size=0.7, stratify=df_final['classification'], random_state=RANDOM_SEED
)
val_df, test_df = train_test_split(
    temp_df, train_size=0.5, stratify=temp_df['classification'], random_state=RANDOM_SEED
)

# 2. Gerador bruto (Sem CLAHE, apenas a normalização obrigatória da ResNet)
datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = datagen.flow_from_dataframe(
    train_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True
)

val_gen = datagen.flow_from_dataframe(
    val_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

test_gen = datagen.flow_from_dataframe(
    test_df, x_col='full_path', y_col='classification',
    target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
# Out:
# Found 800 validated image filenames belonging to 3 classes.
# Found 172 validated image filenames belonging to 3 classes.
# Found 172 validated image filenames belonging to 3 classes.

# %% [markdown]
# # Criação da Rede (ResNet50) e Treinamento Bruto

# %%
def build_model_osteo_resnet_bruto(num_classes=3):
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    base_model.trainable = False  # Pesos da ImageNet congelados

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.3)(x)
    predictions = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Instanciando para 3 classes
model = build_model_osteo_resnet_bruto(num_classes=3)

callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1)
]

print("Iniciando Treinamento Inicial (ResNet50 | 3 Classes | Bruto)...")
history = model.fit(
    train_gen, validation_data=val_gen,
    epochs=EPOCHS, callbacks=callbacks, verbose=1
)

# Salvar o modelo final
model.save(final_model_name)
print(f"Treinamento concluído! Modelo salvo em: {final_model_name}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Iniciando Treinamento Inicial (ResNet50 | 3 Classes | Bruto)...
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.5644 - loss: 1.0620
# Epoch 1: val_loss improved from None to 0.36962, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 447s 17s/step - accuracy: 0.6762 - loss: 0.8146 - val_accuracy: 0.8547 - val_loss: 0.3696
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8418 - loss: 0.4288
# Epoch 2: val_loss improved from 0.36962 to 0.31411, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 470ms/step - accuracy: 0.8537 - loss: 0.3852 - val_accuracy: 0.8779 - val_loss: 0.3141
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.8691 - loss: 0.3396
# Epoch 3: val_loss improved from 0.31411 to 0.29060, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 486ms/step - accuracy: 0.8838 - loss: 0.3173 - val_accuracy: 0.8895 - val_loss: 0.2906
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8820 - loss: 0.3040
# Epoch 4: val_loss improved from 0.29060 to 0.28087, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 476ms/step - accuracy: 0.8800 - loss: 0.2956 - val_accuracy: 0.8721 - val_loss: 0.2809
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9062 - loss: 0.2834
# Epoch 5: val_loss improved from 0.28087 to 0.27092, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 514ms/step - accuracy: 0.9100 - loss: 0.2632 - val_accuracy: 0.8837 - val_loss: 0.2709
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.8974 - loss: 0.2511
# Epoch 6: val_loss improved from 0.27092 to 0.25252, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 484ms/step - accuracy: 0.9100 - loss: 0.2254 - val_accuracy: 0.9128 - val_loss: 0.2525
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9075 - loss: 0.2588
# Epoch 7: val_loss improved from 0.25252 to 0.24712, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 500ms/step - accuracy: 0.9162 - loss: 0.2118 - val_accuracy: 0.8953 - val_loss: 0.2471
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.9412 - loss: 0.1879
# Epoch 8: val_loss improved from 0.24712 to 0.24389, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 501ms/step - accuracy: 0.9325 - loss: 0.1945 - val_accuracy: 0.8953 - val_loss: 0.2439
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9422 - loss: 0.1576
# Epoch 9: val_loss improved from 0.24389 to 0.23725, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 504ms/step - accuracy: 0.9350 - loss: 0.1670 - val_accuracy: 0.9186 - val_loss: 0.2373
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9493 - loss: 0.1305
# Epoch 10: val_loss improved from 0.23725 to 0.22221, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 487ms/step - accuracy: 0.9438 - loss: 0.1525 - val_accuracy: 0.9302 - val_loss: 0.2222
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9522 - loss: 0.1320
# Epoch 11: val_loss did not improve from 0.22221
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 449ms/step - accuracy: 0.9463 - loss: 0.1447 - val_accuracy: 0.9244 - val_loss: 0.2234
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9592 - loss: 0.1067
# Epoch 12: val_loss did not improve from 0.22221
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 400ms/step - accuracy: 0.9500 - loss: 0.1280 - val_accuracy: 0.9360 - val_loss: 0.2237
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.9523 - loss: 0.1317
# Epoch 13: val_loss improved from 0.22221 to 0.21642, saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/melhor_modelo_ResNet50_3classes_bruto_temp.keras
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 447ms/step - accuracy: 0.9513 - loss: 0.1366 - val_accuracy: 0.9186 - val_loss: 0.2164
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.9673 - loss: 0.1008
# Epoch 14: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 451ms/step - accuracy: 0.9613 - loss: 0.1169 - val_accuracy: 0.9186 - val_loss: 0.2250
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9643 - loss: 0.0946
# Epoch 15: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 430ms/step - accuracy: 0.9600 - loss: 0.1072 - val_accuracy: 0.9244 - val_loss: 0.2263
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.9601 - loss: 0.1179
# Epoch 16: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 423ms/step - accuracy: 0.9625 - loss: 0.1135 - val_accuracy: 0.9244 - val_loss: 0.2194
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9627 - loss: 0.1215
# Epoch 17: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 391ms/step - accuracy: 0.9563 - loss: 0.1204 - val_accuracy: 0.9244 - val_loss: 0.2312
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.9607 - loss: 0.1088
# Epoch 18: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 420ms/step - accuracy: 0.9675 - loss: 0.0998 - val_accuracy: 0.9302 - val_loss: 0.2286
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9705 - loss: 0.0985
# Epoch 19: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 448ms/step - accuracy: 0.9675 - loss: 0.1005 - val_accuracy: 0.9244 - val_loss: 0.2294
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9767 - loss: 0.0795
# Epoch 20: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 418ms/step - accuracy: 0.9712 - loss: 0.0838 - val_accuracy: 0.9128 - val_loss: 0.2329
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9813 - loss: 0.0669
# Epoch 21: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 393ms/step - accuracy: 0.9750 - loss: 0.0795 - val_accuracy: 0.9302 - val_loss: 0.2303
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.9731 - loss: 0.0928
# Epoch 22: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 419ms/step - accuracy: 0.9787 - loss: 0.0846 - val_accuracy: 0.9128 - val_loss: 0.2331
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.9720 - loss: 0.0765
# Epoch 23: val_loss did not improve from 0.21642
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 427ms/step - accuracy: 0.9737 - loss: 0.0716 - val_accuracy: 0.9128 - val_loss: 0.2410
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 13.
# Treinamento concluído! Modelo salvo em: /content/drive/MyDrive/TCC/Modelos_Osteosarcoma/ResNet50_Osteosarcoma_3classes_bruto_Final.keras

# %% [markdown]
# # Avaliação Final e Métricas

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# 1. Gráficos de Evolução do Treino
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Treino')
plt.plot(history.history['val_accuracy'], label='Validação')
plt.title('Acurácia (ResNet50 - Bruto)')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Loss (ResNet50 - Bruto)')
plt.legend()
plt.show()

# 2. Predição no conjunto de Teste
test_gen.reset()
Y_pred = model.predict(test_gen)
y_pred = np.argmax(Y_pred, axis=1)
y_true = test_gen.classes
class_labels = list(test_gen.class_indices.keys())

# 3. Relatório de Classificação Detalhado
print("\n--- RELATÓRIO DE CLASSIFICAÇÃO DETALHADO (ResNet50 - BRUTO) ---")
print(classification_report(y_true, y_pred, target_names=class_labels, digits=4))

# 4. Matriz de Confusão
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Classe Predita')
plt.ylabel('Classe Real')
plt.title('Matriz de Confusão - ResNet50 (3 Classes - Bruto)')
plt.show()
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 57s 11s/step
#
# --- RELATÓRIO DE CLASSIFICAÇÃO DETALHADO (ResNet50 - BRUTO) ---
#                   precision    recall  f1-score   support
#
#        Non-Tumor     0.9398    0.9630    0.9512        81
# Non-Viable-Tumor     0.9474    0.9231    0.9351        39
#           Viable     0.9020    0.8846    0.8932        52
#
#         accuracy                         0.9302       172
#        macro avg     0.9297    0.9236    0.9265       172
#     weighted avg     0.9301    0.9302    0.9300       172
